-- %% [markdown]
-- # 1 Regular Languages

-- %% [markdown]
-- ----
-- ## 1.1 Finite Automata
--
-- 단수 automaton 복수 automata
--
-- 유한오토마타(finite automata, FA)를 유한상태기계(finite state machine, FSM)이라고도 함

-- %% [markdown]
-- ### Formal definition of a finite automaton
--
-- * Definition 1.5
--
--   결정적 유한오토마타란 $(Q,\Sigma,\delta,q_0,F)$의 5-튜플이며, 이 때
--     1. $Q$ 상태(state)의 유한집합
--     1. $\Sigma$ 알파벳 - 심볼(symbol)의 유한집합
--     1. $\delta : Q\times\Sigma \to Q$ 전이함수(transition funciton)
--     1. $q_0 \in Q$ 시작 상태(start state)
--     1. $F \subseteq Q$ 종료상태(final state)의 집합
--
--   종료상태 혹은 끝나는 상태를 받아들여지는 상태(accept state)라고도 한다.
--
-- 우선 결정적 유한오토마타(deterministic finite automata, DFA)부터 살펴보자.

-- %%
newtype DFA q a = DFA ([q], [a], (q,a) -> q, q, [q])
{-
   q 상태의 타입
   a 심볼의 타입
   [q] 상태가 여러 개 나열된 타입 (집합 대신 그냥 리스트로 표현)
   [a] 심볼이 여러 개 나열된 타입 (집합 대신 그냥 리스트로 표현)
-}

instance (Show q, Show a) => Show (DFA q a) where
  show (DFA (qs,as,d,q0,fs)) = show (qs,as,dtbl,q0,fs)
      where dtbl = d2tblDFA qs as d

-- 전이함수를 순서쌍 데이타로
d2tblDFA qs as d = [((q,a), d(q,a)) | q<-qs, a<-as]

-- %%
import Data.Maybe (fromJust, fromMaybe)
import Data.List (elemIndex, groupBy, intercalate)

import IHaskell.Display.Graphviz
-- dot "digraph { l -> o; o -> v; v -> e; h -> a ; a -> s; s -> k ; k -> e ; e -> l ; l -> l}"

dfa2graph :: (Eq q, Show q, Show a) => DFA q a -> String
dfa2graph (DFA (qs,as,d,q0,fs))
     = "digraph { node [shape=circle]; rankdir=LR; "
    ++ "thestart [shape=none label=\"\" width=0]; "
    ++ "thestart -> "++show(q2i q0)++"; "
    ++ concat [show i++" [label=\""++(filter (/='"') . show $ i2q i)++"\"]; " | i<-is]
    ++ concat [show(q2i q)++" [shape=doublecircle]; " | q<-fs]
    -- ++ concat [show i++" -> "++show(d'(i,a))++" [label=\""++show a++"\"]; " | i<-is, a<-as] -- 각각 라벨
    ++ concat [ show i++" -> "++show j++" [label=\""++showls ls++"\"]; " | ((i,j),ls) <-es] -- 같은 시작/끝 점 모아 라벨
    ++ "}"
    where
    is = [0 .. length qs-1]
    q2i q = fromJust $ elemIndex q qs
    i2q i = qs !! i
    d'(i,a) = q2i $ d(i2q i,a)
    es = map collectSnd $ groupByFst [((i,d'(i,a)), a) | i<-is, a<-as]
    showls = intercalate "," . map (filter (/='"') . show)

groupByFst = groupBy (\(x1,_) (x2,_) -> x1==x2)
collectSnd ps = (x, ls)
    where (x:_, ls) = unzip ps

drawDFA :: (Eq q, Show q, Show a) => DFA q a -> Graphviz
drawDFA = dot . dfa2graph

-- %%
dfaM1 = DFA (["q1","q2","q3"],[0,1],d,"q1",["q2"])
    where
    d("q1",0) = "q1"; d("q1",1) = "q2"
    d("q2",0) = "q3"; d("q2",1) = "q2"
    d("q3",0) = "q2"; d("q3",1) = "q2"

-- %%
dfaM1
-- Out:
-- (["q1","q2","q3"],[0,1],[(("q1",0),"q1"),(("q1",1),"q2"),(("q2",0),"q3"),(("q2",1),"q2"),(("q3",0),"q2"),(("q3",1),"q2")],"q1",["q2"])

-- %%
dfa2graph dfaM1
drawDFA dfaM1
-- Out:
-- "digraph { node [shape=circle]; rankdir=LR; thestart [shape=none label=\"\" width=0]; thestart -> 0; 0 [label=\"q1\"]; 1 [label=\"q2\"]; 2 [label=\"q3\"]; 1 [shape=doublecircle]; 0 -> 0 [label=\"0\"]; 0 -> 1 [label=\"1\"]; 1 -> 2 [label=\"0\"]; 1 -> 1 [label=\"1\"]; 2 -> 1 [label=\"0,1\"]; }"

-- %%
DFA (_,_,d1,q0,fs) = dfaM1

-- 1101
d1(d1(d1(d1(q0,1),1),0),1) `elem` fs
-- 0110
d1(d1(d1(d1(q0,0),1),1),0) `elem` fs
-- Out:
-- True
-- False

-- %% [markdown]
-- ### Examples of finite automata

-- %%
-- dfaM2

-- %%
-- dfaM3

-- %%
-- dfaM4

-- %%
-- dfaM5

-- %% [markdown]
-- ### Formal defintion of computation
--
-- * Definition 1.6 인식하는 유한오토마타가 존재하는 언어가 정규언어
--
--   a regular language if some finite automaton recognizes it
--
-- * $M$ recognizes language $A$
--
--   if $A = \{w\mid M ~\text{accepts}~ w\}$
--
-- * $M=(Q,\Sigma,\delta,q_0,F)$ accepts $w = a_1a_2a_3\cdots a_n$ where $a_i\in\Sigma$
--
--   if $\delta(\cdots\delta(\delta(\delta(q_0,a_1),a_2),a_3)\cdots,a_n) \in F$
--
--   도식적으로 나타내면
--   $q_0 \stackrel{a_1}{\longrightarrow} r_1
--        \stackrel{a_2}{\longrightarrow} r_2
--        \stackrel{a_3}{\longrightarrow} \cdots
--        \stackrel{a_n}{\longrightarrow} r_n$ where $r_n \in F$

-- %%
(DFA (_,_,d,q0,fs)) `accepts` w = foldl (curry d) q0 w `elem` fs

-- %%
dfaM1 `accepts` []
dfaM1 `accepts` [0]
dfaM1 `accepts` [1]
-- Out:
-- False
-- False
-- True

-- %%
dfaM1 `accepts` [0,0]
dfaM1 `accepts` [0,1]
dfaM1 `accepts` [1,0]
dfaM1 `accepts` [1,1]
-- Out:
-- False
-- True
-- False
-- True

-- %%
dfaM1 `accepts` [1,0,0]
dfaM1 `accepts` [1,0,1]
dfaM1 `accepts` [1,1,0]
dfaM1 `accepts` [1,1,1]
-- Out:
-- True
-- True
-- False
-- True

-- %%
dfaM1 `accepts` [1,1,0,0]
dfaM1 `accepts` [0,1,1,0]
-- Out:
-- True
-- False

-- %% [markdown]
-- ### Designing finite automata
--
-- 교재 정독

-- %% [markdown]
-- ### The regular operations
--
-- * Definition 1.23 두 언어 A와 B에 대한 정규연산 세 가지
--
--     * union $A\cup B$
--     * concatentation $A\cdot B$
--     * star $A^*$
--
--
-- * Theorem 1.25
--
--   The class of regular languages is closed under the union operation
--
--   즉, $A_1$와 $A_2$가 정규언어이면 $A_1\cup A_2$도 정규언어
--
--   증명은 $A_1$을 인식하는 유한오토마타 $M_1$과 $A_2$를 인식하는 유한오토마타 $M_2$로부터
--   $A_1\cup A_2$를 인식하는 유한오토마타를 만들어 낼 수 있음을 보이면 된다. (proof by construction)

-- %% [markdown]
-- 증명 아이디어:
--
-- 우리의 재료
--
-- $M_1 = (Q_1,\Sigma_1,\delta_1,q_{01},F_1)$
--
-- $M_2 = (Q_2,\Sigma_2,\delta_2,q_{02},F_2)$

-- %% [markdown]
-- 재료로 만들어낸 오토마타
-- ($\Sigma_1=\Sigma_2$로 단순한 경우가 아닌 일반적인 경우의 내용을 <span style="color:red">빨간색</span>으로 추가했습니다)
--
-- $M = (Q,\Sigma,\delta,q_0,F)$ 오토마타가
-- $A_1\cup A_2 = \{w \mid w\in A_1 ~\text{또는}~ w\in A_2\}$를 인식하게 만들어 보자
--  * $Q = Q_1 \times Q_2$ 두 오토마타 상태집합의 카테시안곱<br>
--    <span style="color:red">일반적으로 $Q = (Q_1\cup\{q_\bot\}) \times (Q_2\cup\{q_\bot\})$. 단, "실패 상태"를 의미하는 $q_\bot\notin Q_1\cup Q_2$.</span>
--  * 원래는 $\Sigma = \Sigma_1 \cup \Sigma_2$ 두 오토마타 알파벳의 합집합이어야 하지만<br>
--    지금은 단순한 경우부터 $\Sigma=\Sigma_1=\Sigma_2$
--  * $q_0 = (q_{01},q_{02})$ 두 오토마타 시작상태로 이루어진 순서쌍
--  * $F = \{ (q_1,q_2) \mid q_1\in F_1 ~\text{또는}~q_2\in F_2\} = (Q_1\times F_2) \cup (F_1\times Q_2)$
--  * 참고로, 아래 $\delta$의 정의에서 $q_1\in Q_1$, $q_2\in Q_2$, $q_1'\in Q_1\cup\{q_\bot\}$, $q_1'\in Q_1\cup\{q_\bot\}$<br>
--    $\begin{align*}
--    \delta(\;(q_1,q_2),~a\;) &= (\; \delta_1(q_1,a) ,~ \delta_2(q_2,a) \;) & \color{red}{a\in\Sigma_1, a\in\Sigma_2} \\
--    \color{red}{\delta(\;(q_1',q_2'),~a\;)} & \color{red}{\;= (\; q_\bot ,~ \delta_2'(q_2,a) \;)} & \color{red}{a\notin \Sigma_1, a\in\Sigma_2} \\
--    \color{red}{\delta(\;(q_1',q_2'),~a\;)} & \color{red}{\;= (\; \delta_1'(q_1,a) ,~ q_\bot \;)} & \color{red}{a\in\Sigma_1, a\notin \Sigma_2}
--    \end{align*}$<br>
--    <span style="color:red">
--     위에서 $\delta_1'$, $\delta_2'$는 첫째 인자 $q_1\in Q_1$, $q_2\in Q_2$인 경우는 $\delta_1$, $\delta_2$와 같이 동작하고,<br>
--     그렇지 않으면, 즉 첫째 인자가 실패 상태인 $q_\bot$인 경우는 그 결과값(즉, 다음 상태)도 $q_\bot$이 된다.
--    </span>

-- %% [markdown]
-- 정말로 $M$이 인식하는 언어가 $A_1\cup A_2$ 인지 확인을 해보자.
--
-- $M=(Q,\Sigma,\delta,q_0,F)$ accepts $w = a_1a_2a_3\cdots a_n$ where $a_i\in\Sigma$
--
--   if $\delta(\cdots\delta(\delta(\delta(q_0,a_1),a_2),a_3)\cdots,a_n) \in F$
--
--   도식적으로 나타내면
--   $q_0 \stackrel{a_1}{\longrightarrow} r_1
--        \stackrel{a_2}{\longrightarrow} r_2
--        \stackrel{a_3}{\longrightarrow} \cdots
--        \stackrel{a_n}{\longrightarrow} r_n$ where $r_n \in F$

-- %% [markdown]
-- $\delta(\cdots\delta(\delta(\delta(q_0,a_1),a_2),a_3)\cdots,a_n) \in F$ 이걸 검사

-- %% [markdown]
-- $\delta(\cdots\delta(\delta(\delta((q_{01},q_{02}),a_1),a_2),a_3)\cdots,a_n) \in F$

-- %% [markdown]
-- $\delta(\cdots\delta(\delta( \;(\delta_1(q_{01},a_1),\delta_2(q_{02},a_1)),\;a_2\;),a_3)\cdots,a_n) \in F$

-- %% [markdown]
-- $\delta(\cdots\delta((\;\delta_1(\delta_1(q_{01},a_1),a_2),\delta_2(\delta_2(q_{02},a_1),a_2)\;),a_3)\cdots,a_n) \in F$

-- %% [markdown]
-- $(\;\delta_1(\cdots\delta_1(\delta_1(\delta_1(q_{01},a_1),a_2),a_3)\cdots,a_n)
--  ~,~\delta_2(\cdots\delta_2(\delta_2(\delta_2(q_{02},a_1),a_2),a_3)\cdots,a_n)\;)
--   \in F$

-- %% [markdown]
-- 그런데 $F =  \{ (q_1,q_2) \mid q_1\in F_1 ~\text{또는}~q_2\in F_2\}$이므로

-- %% [markdown]
-- $\delta_1(\cdots\delta_1(\delta_1(\delta_1(q_{01},a_1),a_2),a_3)\cdots,a_n) \in F_1$
-- 또는
-- $\delta_2(\cdots\delta_2(\delta_2(\delta_2(q_{02},a_1),a_2),a_3)\cdots,a_n) \in F_2$
-- 인지 검사

-- %% [markdown]
-- $M_1$ accepts $w$ 또는 $M_2$ accepts $w$ 인지 검사
--
-- $w\in A_1$ 또는 $w\in A_2$ 인지 검사
--
-- $w\in A_1\cup A_2$ 인지 검사
--
-- 그러니까 우리가 새로 만든 $M$이 $A_1\cup A_2$를 인식하는 오토마타가 진짜로 확실히 맞구나! 라는 걸 확인

-- %%
-- 단순한 경우
unionDFA :: (Eq q1, Eq q2, Eq a) => DFA q1 a -> DFA q2 a -> DFA (q1,q2) a
unionDFA (DFA (qs1,as1,d1,q01,fs1)) (DFA (qs2,as2,d2,q02,fs2))
    | as1 == as2 = DFA (qs,as,d,q0,fs)
    | otherwise  = error "not the same alphabet"
    where
    qs = [(q1,q2) | q1<-qs1, q2<-qs2] -- cartesian product
    as = as1
    q0 = (q01,q02)
    fs = [(q1,q2) | (q1,q2) <- qs, q1 `elem` fs1 || q2 `elem` fs2]
    d((q1,q2),a) = (d1(q1,a), d2(q2,a))

-- %%
-- 1이 나타나는 회수가 3으로 나눈 나머지 1인 경우를 받아들임
m1 = DFA (["p0","p1","p2"],[0,1], d1, "p0", ["p1"])
    where
    d1("p0",0) = "p0"; d1("p0",1) = "p1"
    d1("p1",0) = "p1"; d1("p1",1) = "p2"
    d1("p2",0) = "p2"; d1("p2",1) = "p0"
m1
drawDFA m1
-- Out:
-- (["p0","p1","p2"],[0,1],[(("p0",0),"p0"),(("p0",1),"p1"),(("p1",0),"p1"),(("p1",1),"p2"),(("p2",0),"p2"),(("p2",1),"p0")],"p0",["p1"])

-- %%
-- 1이 나타나는 회수가 홀수인 경우를 받아들임
m2 = DFA (["q0","q1"],     [0,1], d2, "q0", ["q1"])
    where
    d2("q0",0) = "q0"; d2("q0",1) = "q1"
    d2("q1",0) = "q1"; d2("q1",1) = "q0"
m2
drawDFA m2
-- Out:
-- (["q0","q1"],[0,1],[(("q0",0),"q0"),(("q0",1),"q1"),(("q1",0),"q1"),(("q1",1),"q0")],"q0",["q1"])

-- %%
-- 1이 나타나는 회수가 6으로 나눈 나머지 1,3,4,5인 경우를 받아들임
m = unionDFA m1 m2

m

drawDFA m
-- Out:
-- ([("p0","q0"),("p0","q1"),("p1","q0"),("p1","q1"),("p2","q0"),("p2","q1")],[0,1],[((("p0","q0"),0),("p0","q0")),((("p0","q0"),1),("p1","q1")),((("p0","q1"),0),("p0","q1")),((("p0","q1"),1),("p1","q0")),((("p1","q0"),0),("p1","q0")),((("p1","q0"),1),("p2","q1")),((("p1","q1"),0),("p1","q1")),((("p1","q1"),1),("p2","q0")),((("p2","q0"),0),("p2","q0")),((("p2","q0"),1),("p0","q1")),((("p2","q1"),0),("p2","q1")),((("p2","q1"),1),("p0","q0"))],("p0","q0"),[("p0","q1"),("p1","q0"),("p1","q1"),("p2","q1")])

-- %% [markdown]
-- ----
-- 교과서도 그렇고 위에 설명한 것도 교과서를 따라서 증명에서 두 DFA의 알파벳이 같은 경우,
-- 즉 $\Sigma_1 = \Sigma_2$인 특별한 경우만을 증명했다. 여기에서도 그 설명을 따라가고
-- 방금 전까지 위에서 본 코드도 그에 따라 작성된 것이다.
--
-- 그렇다면 일반적인 경우에는 어떻게 해야 될까?
-- Designing Finite Automata 부분에 관련 설명이 있을 줄 알았는데 없어서
-- (아마 나중에 NFA와 DFA의 관계를 설명할 때 나올 거 같기도 함),
-- 수업시간에 추가로 설명한 것처럼 기존의 두 DFA 없던 새로운 "실패 상태"를 추가해 해결한다.
-- 일반적인 경우에 대해 추가해야 할 사항을 빨간색으로 위의 증명 과정 설명에 표시해 두었다.
--
-- 아래에는 코드에 이를 반영한 하스켈 프로그램 구현과 실행예를 작성하였다.

-- %%
import Data.List (union)

unionDFA' :: (Eq q1, Eq q2, Eq a) => DFA q1 a -> DFA q2 a -> q1 -> q2 -> DFA (q1,q2) a
unionDFA' (DFA (qs1,as1,d1,q01,fs1)) (DFA (qs2,as2,d2,q02,fs2)) qb1 qb2
    | qb1 `elem` qs1 = error "fail state qb1 must be fresh from qs1" 
    | qb2 `elem` qs2 = error "fail state qb2 must be fresh from qs2" 
    | otherwise      = DFA (qs, as,d,q0,fs)
    where
    qs = [(q1,q2) | q1<-qs1++[qb1], q2<-qs2++[qb2]] -- cartesian product
    as = as1 `union` as2
    q0 = (q01,q02)
    fs = [(q1,q2) | (q1,q2) <- qs, q1 `elem` fs1 || q2 `elem` fs2]
    d((q1,q2),a) = (d1'(q1,a), d2'(q2,a))
    d1'(q1,a) | q1 `elem` qs1 && a `elem` as1  = d1(q1,a)
              | otherwise                      = qb1
    d2'(q2,a) | q2 `elem` qs2 && a `elem` as2  = d2(q2,a)
              | otherwise                      = qb2

-- %%
-- 0과 1이 나타날 수 있는데, 그 중 1이 나타나는 회수가 홀수인 경우를 받아들임
m1' = DFA (["q0","q1"],     [0,1], d2, "q0", ["q1"])
    where
    d2("q0",0) = "q0"; d2("q0",1) = "q1"
    d2("q1",0) = "q1"; d2("q1",1) = "q0"
m1'
drawDFA m1'
-- Out:
-- (["q0","q1"],[0,1],[(("q0",0),"q0"),(("q0",1),"q1"),(("q1",0),"q1"),(("q1",1),"q0")],"q0",["q1"])

-- %%
--  1과 2가 나타날 수 있는데, 그 중 1이 나타나는 회수가 홀수인 경우를 받아들임
m2' = DFA (["p0","p1"],     [1,2], d2, "p0", ["p1"])
    where
    d2("p0",2) = "p0"; d2("p0",1) = "p1"
    d2("p1",2) = "p1"; d2("p1",1) = "p0"
m2'
drawDFA m2'
-- Out:
-- (["p0","p1"],[1,2],[(("p0",1),"p1"),(("p0",2),"p0"),(("p1",1),"p0"),(("p1",2),"p1")],"p0",["p1"])

-- %%
m' = unionDFA' m1' m2' "_" "_"

m'

drawDFA m'
-- Out:
-- ([("q0","p0"),("q0","p1"),("q0","_"),("q1","p0"),("q1","p1"),("q1","_"),("_","p0"),("_","p1"),("_","_")],[0,1,2],[((("q0","p0"),0),("q0","_")),((("q0","p0"),1),("q1","p1")),((("q0","p0"),2),("_","p0")),((("q0","p1"),0),("q0","_")),((("q0","p1"),1),("q1","p0")),((("q0","p1"),2),("_","p1")),((("q0","_"),0),("q0","_")),((("q0","_"),1),("q1","_")),((("q0","_"),2),("_","_")),((("q1","p0"),0),("q1","_")),((("q1","p0"),1),("q0","p1")),((("q1","p0"),2),("_","p0")),((("q1","p1"),0),("q1","_")),((("q1","p1"),1),("q0","p0")),((("q1","p1"),2),("_","p1")),((("q1","_"),0),("q1","_")),((("q1","_"),1),("q0","_")),((("q1","_"),2),("_","_")),((("_","p0"),0),("_","_")),((("_","p0"),1),("_","p1")),((("_","p0"),2),("_","p0")),((("_","p1"),0),("_","_")),((("_","p1"),1),("_","p0")),((("_","p1"),2),("_","p1")),((("_","_"),0),("_","_")),((("_","_"),1),("_","_")),((("_","_"),2),("_","_"))],("q0","p0"),[("q0","p1"),("q1","p0"),("q1","p1"),("q1","_"),("_","p1")])

-- %%
import Data.List (sort, intersect)

trimUnreachableDFA (DFA (qs,as,d,q0,fs)) = DFA (qs',as,d,q0,fs')
    where
    qs' = reachable as d [q0]
    fs' = fs `intersect` qs'

reachable as d rs
    | length rs == length rs' = rs'
    | otherwise               = reachable as d rs'
    where rs' = sort $ rs `union` [d(r,a) | r<-rs, a<-as]

-- %%
drawDFA $ trimUnreachableDFA m'

-- %% [markdown]
-- ----
-- ## 1.2 Nondeterminism
--
-- 정규언어가 union 말고 나머지 두 정규연산인 concatenation과 star에 대해서도 닫혀있다는 것을 보이는 데
-- 비결정적 유한오토마타(nondeterministic finite automata, NFA)를 써먹을 수 있다.

-- %% [markdown]
-- ### Formal defintion of a nondeterministic finite automata
--
-- * Definition 1.37
--
--   비결정적 유한오토마타란 $(Q,\Sigma,\delta,q_0,F)$의 5-튜플이며, 이 때
--     1. $Q$ 상태(state)의 유한집합
--     1. $\Sigma$ 알파벳 - 심볼(symbol)의 유한집합
--     1. $\delta : Q\times\Sigma_\varepsilon \to \wp(Q)$ 전이함수(transition funciton). 여기서 $\Sigma_\varepsilon = \Sigma\cup\{\varepsilon\}$
--     1. $q_0 \in Q$ 시작 상태(start state)
--     1. $F \subseteq Q$ 종료상태(final state)의 집합

-- %%
newtype NFA q a = NFA ([q], [a], (q,[a]) -> [q], q, [q])
{-
   q 상태의 타입
   a 심볼의 타입
   [q] 상태가 여러 개 나열된 타입 (집합 대신 그냥 리스트로 표현)
   [a] 심볼이 여러 개 나열된 타입 (집합 대신 그냥 리스트로 표현)
   
   전이함수의 타입은 사실 (q,Maybe a) -> [q] 가 좀더 정확하지만
   그냥 [a]를 Maybe a대신에 쓰되 원소가 없거나 1개가 들어있는 리스트만 고려한다
   이건 그냥 []가 Nothing보다 짧고 [x]가 Just x보다 타이핑하기 짧아서 ... 
-}

instance (Show q, Show a) => Show (NFA q a) where
  show (NFA (qs,as,d,q0,fs)) = show (qs,as,dtbl,q0,fs)
      where dtbl = d2tblNFA qs as d

-- 전이함수를 순서쌍 데이타로
d2tblNFA qs as d = [((q,x), d(q,x)) | q<-qs, x<-[[a] |a<-as]++[[]]]

-- %%
import Data.Maybe (fromJust,fromMaybe)
import Data.List (elemIndex, groupBy, intercalate)

import IHaskell.Display.Graphviz
-- dot "digraph { l -> o; o -> v; v -> e; h -> a ; a -> s; s -> k ; k -> e ; e -> l ; l -> l}"

nfa2graph :: (Eq q, Show q, Show a) => NFA q a -> String
nfa2graph (NFA (qs,as,d,q0,fs))
     = "digraph { node [shape=circle]; rankdir=LR; "
    ++ "thestart [shape=none label=\"\" width=0]; "
    ++ "thestart -> "++show(q2i q0)++"; "
    ++ concat [show i++" [label=\""++(filter (/='"') . show $ i2q i)++"\"]; " | i<-is]
    ++ concat [show(q2i q)++" [shape=doublecircle]; " | q<-fs]
    -- ++ concat [show i++" -> "++show(d'(i,a))++" [label=\""++show a++"\"]; " | i<-is, a<-as] -- 각각 라벨
    ++ concat [ show i++" -> "++show j++" [label=\""++showls ls++"\"]; " | ((i,j),ls) <-es] -- 같은 시작/끝 점 모아 라벨
    ++ "}"
    where
    is = [0 .. length qs-1]
    q2i q = fromJust $ elemIndex q qs
    i2q i = qs !! i
    d'(i,x) = map q2i $ d(i2q i,x)
    es = map collectSnd $ groupByFst [((i,j), x) | i<-is, x<-[[a]|a<-as]++[[]], j<-d'(i,x)]
    showls = intercalate "," . map (\l -> if null l then "ε" else filter (/='"') (show $ head l))

groupByFst = groupBy (\(x1,_) (x2,_) -> x1==x2)
collectSnd ps = (x, ls)
    where (x:_, ls) = unzip ps

drawNFA :: (Eq q, Show q, Show a) => NFA q a -> Graphviz
drawNFA = dot . nfa2graph

-- %%
nfaN1 = NFA (["q1","q2","q3","q4"],[0,1],d,"q1",["q4"])
    where
    d("q1",[0]) = ["q1"]
    d("q1",[1]) = ["q1","q2"]
    d("q2",[0]) = ["q3"]
    d("q2",[] ) = ["q3"] -- epsilon move
    d("q3",[1]) = ["q4"]
    d("q4",[0]) = ["q4"]
    d("q4",[1]) = ["q4"]
    d( _  , _ ) = []

nfaN1

drawNFA nfaN1
-- Out:
-- (["q1","q2","q3","q4"],[0,1],[(("q1",[0]),["q1"]),(("q1",[1]),["q1","q2"]),(("q1",[]),[]),(("q2",[0]),["q3"]),(("q2",[1]),[]),(("q2",[]),["q3"]),(("q3",[0]),[]),(("q3",[1]),["q4"]),(("q3",[]),[]),(("q4",[0]),["q4"]),(("q4",[1]),["q4"]),(("q4",[]),[])],"q1",["q4"])

-- %% [markdown]
-- ----
-- 순간이동, 그러니까 $\varepsilon$ 전이가 포함된 NFA의 경우 어떤 상태에서 하나의 심볼을 보면 이동할 수 있는
-- 다음 상태의 집합을 구하는 것은 전이함수 $\delta$를 한 번만 계산해서는 안 되고 여러 번 활용해야 하는 경우가 생긴다.
--
-- 참고로 한 번의 NFA 상태전이 $q\in\delta(r,x)$를 $r \stackrel{x}{\longrightarrow}q$로 나타낸다.<br>
-- $r$로부터 0회 이상 여러 번 반복된 상태전이를 통해 $q$에 도달하였고 그동안의 라벨을 이어붙인 문자열이 $w$라면 $r \stackrel{w~}{\longrightarrow^*}q$로 나타낸다.
--
-- 이렇게 한 개의 심볼(글자)를 처리하면 어디까지 전이할 수 있는지 계산하기 위해 고안된 개념이 $\varepsilon$-closure 이며, 아래와 같이 정의할 수 있다.
--
-- $\mathcal{E} : \wp(Q) \to \wp(Q)$<br>
-- $\mathcal{E}(R) = \big\{ q \mid r \in R,~r \stackrel{\varepsilon~}{\longrightarrow^*}q \big\}$

-- %%
import Data.List (union, intersect, sort)

eclosure :: Ord q => ( (q,[a]) -> [q] ) -> [q] -> [q]
eclosure d rs
    | length rs == length rs' = rs'
    | otherwise               = eclosure d rs'
    where
    rs' = sort $ foldr union rs [d(r,[]) | r<-rs]

-- %% [markdown]
-- $M=(Q,\Sigma,\delta,q_0,F)$ accepts $w = a_1a_2a_3\cdots a_n$ where $a_i\in\Sigma$
--
-- if
-- $\delta_\varepsilon(\cdots\delta_\varepsilon(\delta_\varepsilon(\delta_\varepsilon(\mathcal{E}(\{q_0\}),a_1),a_2),a_3)\cdots,a_n) \cap F \neq \emptyset$
-- <br>
-- where
-- <br>
-- $\delta_\varepsilon : \wp(Q) \times \Sigma \to \wp(Q)$<br>
-- $\displaystyle\delta_\varepsilon(R,a) =  \mathcal{E}\left( \bigcup_{r\,\in\,R} \delta(r,a) \right)$

-- %%
NFA (_,_,d1,_,_) = nfaN1

-- 010110

-- 그냥 델타함수를 사용한 경우는 화살표 한개만 따라가죠 (epsilon move 고려 안됨)
d1("q1",[0])
d1("q1",[1]) -- q3는 나오지 않는다 왜냐하면 q3로 가려면 epsilon move가 필요하기 때문
-- ...
-- ...
-- Out:
-- ["q1"]
-- ["q1","q2"]

-- %%
NFA (_,_,d1,_,_) = nfaN1
-- 엡실론 클로저 함수
eclos1 = eclosure d1
-- 델테엡실론 함수 정의
de1(rs,a) = eclos1 $ foldr union [] [d1(r,[a]) | r<-eclos1 rs]

-- 010110

-- 델다엡실론 함수를 사용한 경우
de1(eclos1["q1"],0)
de1(["q1"],1)
de1(["q1","q2","q3"],0)
de1(["q1","q3"],1)
de1(["q1","q2","q3","q4"],1)
de1(["q1","q2","q3","q4"],0)
-- Out:
-- ["q1"]
-- ["q1","q2","q3"]
-- ["q1","q3"]
-- ["q1","q2","q3","q4"]
-- ["q1","q2","q3","q4"]
-- ["q1","q3","q4"]

-- %%
accepts_ :: Ord q => NFA q a -> [a] -> Bool
(NFA (_,as,d,q0,fs)) `accepts_` w = not . null $ foldl (curry de) (eclos [q0]) w `intersect` fs
    where
    eclos = eclosure d
    de(rs,a) = eclos $ foldr union [] [d(r,[a]) | r<-rs]

-- %%
-- Figure 1.29
nfaN1 `accepts_` [0,1,0,1,1,0]
-- Out:
-- True

-- %%
nfaN1 `accepts_` [1,0,1]
nfaN1 `accepts_` [1,1]
-- Out:
-- True
-- True

-- %%
nfaN1 `accepts_` [1,0,0]
nfaN1 `accepts_` [0,1,0]
-- Out:
-- False
-- False

-- %%
-- nfaN2

-- %%
-- nfaN3
nfaN3 = NFA (["r0","q0","q1","p0","p1","p2"],[0],d,"r0",["q0","p0"])
    where
    d("r0",[] ) = ["q0","p0"] -- epsilon move
    d("q0",[0]) = ["q1"]
    d("q1",[0]) = ["q0"]
    d("p0",[0]) = ["p1"]
    d("p1",[0]) = ["p2"]
    d("p2",[0]) = ["p0"]
    d( _  , _ ) = []

nfaN3

drawNFA nfaN3
-- Out:
-- (["r0","q0","q1","p0","p1","p2"],[0],[(("r0",[0]),[]),(("r0",[]),["q0","p0"]),(("q0",[0]),["q1"]),(("q0",[]),[]),(("q1",[0]),["q0"]),(("q1",[]),[]),(("p0",[0]),["p1"]),(("p0",[]),[]),(("p1",[0]),["p2"]),(("p1",[]),[]),(("p2",[0]),["p0"]),(("p2",[]),[])],"r0",["q0","p0"])

-- %% [markdown]
-- ### Equivalenceof NFAs and DFAs
--
-- DFA와 같은 일을 하는 NFA가 있음을 보이는 것은 간단하다

-- %%
dfa2nfa :: DFA q a -> NFA q a
dfa2nfa (DFA (qs,as,d,q0,fs)) = NFA (qs,as,d',q0,fs)
    where
    d'(_,[] ) = [] -- no epslion moves
    d'(r,[a]) = [d(r,a)]

-- %% [markdown]
-- Theorem 1.39 모든 NFA는 그와 같은 일을 하는 DFA가 있다

-- %%
nfa2dfa (NFA (qs,as,d,q0,fs)) = DFA (qs',as,d',q0',fs')
    where
    qs' = powerset qs
    fs' = [rs | rs<-qs', not . null $ rs `intersect` fs]
    eclos = eclosure d
    q0' = eclos [q0]
    d'(rs,a) = eclos $ foldr union [] [d(r,[a]) | r<-rs]

powerset :: [a] ->  [[a]]
powerset []     = [[]]
powerset (x:xs) = powerset xs ++ map (x:) (powerset xs)

-- %%
nfaN4 = NFA ([1,2,3],["a","b"],d,1,[1])
    where
    d(1,["b"]) = [2]
    d(1,[]   ) = [3]
    d(2,["a"]) = [2,3]
    d(2,["b"]) = [3]
    d(3,["a"]) = [1]
    d(_,_    ) = []

drawNFA nfaN4

-- %%
dfaN4 = nfa2dfa nfaN4

dfaN4

drawDFA dfaN4
-- Out:
-- ([[],[3],[2],[2,3],[1],[1,3],[1,2],[1,2,3]],["a","b"],[(([],"a"),[]),(([],"b"),[]),(([3],"a"),[1,3]),(([3],"b"),[]),(([2],"a"),[2,3]),(([2],"b"),[3]),(([2,3],"a"),[1,2,3]),(([2,3],"b"),[3]),(([1],"a"),[]),(([1],"b"),[2]),(([1,3],"a"),[1,3]),(([1,3],"b"),[2]),(([1,2],"a"),[2,3]),(([1,2],"b"),[2,3]),(([1,2,3],"a"),[1,2,3]),(([1,2,3],"b"),[2,3])],[1,3],[[1],[1,3],[1,2],[1,2,3]])

-- %%
dfaN4' = trimUnreachableDFA dfaN4

dfaN4'

drawDFA dfaN4'
-- Out:
-- ([[],[1,2,3],[1,3],[2],[2,3],[3]],["a","b"],[(([],"a"),[]),(([],"b"),[]),(([1,2,3],"a"),[1,2,3]),(([1,2,3],"b"),[2,3]),(([1,3],"a"),[1,3]),(([1,3],"b"),[2]),(([2],"a"),[2,3]),(([2],"b"),[3]),(([2,3],"a"),[1,2,3]),(([2,3],"b"),[3]),(([3],"a"),[1,3]),(([3],"b"),[])],[1,3],[[1,3],[1,2,3]])

-- %% [markdown]
-- ### Closure under the regular operations
--
-- union 연산의 닫힘을 DFA를 이용해 보였던 것처럼
-- concat, star 연산의 닫힘을 NFA를 이용해 보일 수 있음

-- %%
-- Theorem 1.45 NFA를 이용한 정규언어의 합집합 연산에 대한 닫힘
unionNFA (NFA (qs1,as1,d1,q01,fs1)) (NFA (qs2,as2,d2,q02,fs2)) q0
  | not . null $ qs1 `intersect` qs2 = error "NFA states must be disjoint"
  | q0 `elem` qs1 || q0 `elem` qs2   = error "new start state q0 must be fresh"
  | otherwise = NFA (qs,as,d,q0,fs)
  where
  qs = [q0] `union` qs1 `union` qs2
  as = as1 `union` as2
  fs = fs1 `union` fs2
  d(q,[])
    | q == q0   = [q01,q02]                 -- new epsilon moves
    | otherwise = d1(q,[]) `union` d2(q,[]) -- existing epsilon moves
  d(q,a)
    | q == q0   = []
    | otherwise = d1(q,a)  `union` d2(q,a)

-- %%
nfaN3_1 = NFA (["q0","q1"],[0],d,"q0",["q0"])
    where
    d("q0",[0]) = ["q1"]
    d("q1",[0]) = ["q0"]
    d( _  , _ ) = []

nfaN3_1
drawNFA nfaN3_1
-- Out:
-- (["q0","q1"],[0],[(("q0",[0]),["q1"]),(("q0",[]),[]),(("q1",[0]),["q0"]),(("q1",[]),[])],"q0",["q0"])

-- %%
nfaN3_2 = NFA (["p0","p1","p2"],[0],d,"p0",["p0"])
    where
    d("p0",[0]) = ["p1"]
    d("p1",[0]) = ["p2"]
    d("p2",[0]) = ["p0"]
    d( _  , _ ) = []

nfaN3_2
drawNFA nfaN3_2
-- Out:
-- (["p0","p1","p2"],[0],[(("p0",[0]),["p1"]),(("p0",[]),[]),(("p1",[0]),["p2"]),(("p1",[]),[]),(("p2",[0]),["p0"]),(("p2",[]),[])],"p0",["p0"])

-- %%
unionNFA nfaN3_1 nfaN3_2 "r0"
-- Out:
-- (["r0","q0","q1","p0","p1","p2"],[0],[(("r0",[0]),[]),(("r0",[]),["q0","p0"]),(("q0",[0]),["q1"]),(("q0",[]),[]),(("q1",[0]),["q0"]),(("q1",[]),[]),(("p0",[0]),["p1"]),(("p0",[]),[]),(("p1",[0]),["p2"]),(("p1",[]),[]),(("p2",[0]),["p0"]),(("p2",[]),[])],"r0",["q0","p0"])

-- %%
drawNFA (unionNFA nfaN3_1 nfaN3_2 "r0")

-- %%
-- Theorem 1.48 NFA를 이용한 정규언어의 이어붙이기(concnat) 연산에 대한 닫힘
concatNFA (NFA (qs1,as1,d1,q01,fs1)) (NFA (qs2,as2,d2,q02,fs2))
  | not . null $ qs1 `intersect` qs2 = error "NFA states must be disjoint"
  | otherwise = NFA (qs,as,d,q01,fs)
  where
  qs = qs1 `union` qs2
  as = as1 `union` as2
  fs = fs2
  d(q,[])
    | q `elem` fs1 = [q02] -- 첫째 기계의 종료상태이면 둘째 기계의 시작상태로 순간이동
    | otherwise = d1(q,[]) `union` d2(q,[]) -- existing epsilon moves
  d(q,a)
    | otherwise = d1(q,a)  `union` d2(q,a)
-- Out:
-- Line 12: Redundant guard
-- Found:
-- d (q, a) | otherwise = d1 (q, a) `union` d2 (q, a)
-- Why not:
-- d (q, a) = d1 (q, a) `union` d2 (q, a)

-- %%
drawNFA nfaN3_1

-- %%
drawNFA nfaN3_2

-- %%
drawNFA (concatNFA nfaN3_1 nfaN3_2)

-- %%
nfaN3_1' = NFA (["q0","q1"],[0],d,"q0",["q1"])
    where
    d("q0",[0]) = ["q1"]
    d("q1",[0]) = ["q0"]
    d( _  , _ ) = []

drawNFA nfaN3_1'

-- %%
nfaN3_2' = NFA (["p0","p1","p2"],[0],d,"p0",["p1"])
    where
    d("p0",[0]) = ["p1"]
    d("p1",[0]) = ["p2"]
    d("p2",[0]) = ["p0"]
    d( _  , _ ) = []

drawNFA nfaN3_2'

-- %%
drawNFA (concatNFA nfaN3_1' nfaN3_2')

-- %%
-- Theorem 1.49 NFA를 이용한 정규언어의 star 연산에 대한 닫힘
starNFA (NFA (qs1,as1,d1,q01,fs1)) q0
  | q0 `elem` qs1 = error "new start state q0 must be fresh"
  | otherwise = NFA (qs,as1,d,q0,fs)
  where
  qs = [q0] `union` qs1
  fs = [q0] `union` fs1
  d(q,[])
    | q == q0      = [q01] -- 새로운 시작상태에서 원래 기계 시작상태로 순간이동
    | q `elem` fs1 = [q01] -- 원래 기계 종료상태에서 원래 기계시작상태로 순간이동
    | otherwise = d1(q,[]) -- existing epsilon moves
  d(q,a)
    | otherwise = d1(q,a)
-- Out:
-- Line 12: Redundant guard
-- Found:
-- d (q, a) | otherwise = d1 (q, a)
-- Why not:
-- d (q, a) = d1 (q, a)

-- %%
drawNFA nfaN3_2'

-- %%
drawNFA (starNFA nfaN3_2' "r0")

-- %% [markdown]
-- ----
-- ## 1.3 Regular Expression

-- %% [markdown]
-- ### Formal definition of a regular expression
--
-- * Definition 1.52
--
--   다음과 같은 방법으로 구성되는 $R$을 정규식이라 또는 정규표현식이라 한다. 오른쪽에는 정규식이 나타내는 언어를 설명하였다.
--
--   1. $a\in \Sigma\qquad$ $\{a\}$를 나타냄
--   1. $\varepsilon\quad\qquad$ $\{\varepsilon\}$을 나타냄
--   1. $\emptyset\quad\qquad$ 공집합을 나타냄
--   1. $R_1 | R_2\quad$ 정규식 $R_1$과 $R_2$가 나타내는 언어의 합집합(union)을 나타냄
--   1. $R_1 R_2\quad$ 정규식 $R_1$과 $R_2$가 나타내는 언어의 이어붙임(concat)을 나타냄
--   1. $R_1^*\qquad$ 정규식 $R_1$나 나타내는 언어의 0회 이상 반복(star)를 나타냄
--
-- 정규식 표기는 $\Sigma\cup\{\varepsilon, \emptyset, |, *\}$를 알파벳으로 하나는 언어로 볼 수 있으며
-- 정규식의 언어를 $\mathcal{R}$이라 표기한다.
--
-- 그러니까 $R\in\mathcal{R}$

-- %%
data RE a = Symbol a
          | Epsilon 
          | Empty
          | Union (RE a) (RE a)
          | Concat (RE a) (RE a)
          | Star (RE a)
          deriving Eq

instance Show a => Show (RE a) where
  show (Symbol a) = show a
  show Epsilon = "ε"
  show Empty = "∅"
  show (Union r1 r2) = show r1++"|"++show r2
  show (Concat r1 r2) = showU r1 ++ showU r2
  show (Star r) = showUC r++"*"

showU r@(Union _ _) = "("++show r++")"
showU r             = show r

showUC r@(Concat _ _) = "("++show r++")"
showUC r              = showU r

-- %%
Epsilon
Empty
Symbol 0
Symbol 0 `Union` Concat (Symbol 1) (Star (Symbol 0))
Star(Symbol 0 `Union` Concat (Symbol 1) (Star (Symbol 0)))
-- Out:
-- ε
-- ∅
-- 0
-- 0|10*
-- (0|10*)*

-- %% [markdown]
-- ### Equivalence with finite automata
--
-- 정규식에 해당하는 NFA를 찾는 것은 정규연산의 닫힘에 대한 내용을 따라 진행하면 된다.
--
-- 반대로 DFA에 해당하는 정규식을 찾는 것은 NFA를 일반화하여 정규식으로 라벨된 GNFA라는 것을 이용한다.
--
-- * Definition 1.64 GNFA
--
--   $M=(Q,\Sigma,\delta,q_\mathrm{start},q_\mathrm{final})$
--     1. $Q$ 상태의 유한집합
--     1. $\Sigma$ 알파벳 - 심볼의 유한집합
--     1. $\delta : (Q-\{q_\mathrm{final}\}) \times (Q-\{q_\mathrm{start}\}) \to \mathcal{R}$ 전이함수
--     1. $q_\mathrm{start}$ 시작상태
--     1. $q_\mathrm{final}$ 종료상태
--
-- NFA와 달리 GNFA의 종료상태는 항상 1개로 정해져 있다.
--
-- 또한 전이함수의 타입에서 알 수 있듯,
--  * 시작과 종료상태를 제외한 모든 상태에서 자기 자신을 포함한 모든 상태로 전이하는 화살표가 있다.
--  * 그리고 시작 상태에서는 들어오는 화살표는 없지만 다른 모든 상태로 나가는 화살표가 있으며,
--  * 반대로 종료 상태에서는 나가는 화살표는 없지만 다른 모든 상태에서 들어오는 화살표가 있다.

-- %%
newtype GNFA q a = GNFA ([q], [a], (q,q) -> RE a, q, q)

instance (Show q, Show a) => Show (GNFA q a) where
  show (GNFA (qs,as,d,q0,qf)) = show (qs,as,dtbl,q0,qf)
      where dtbl = d2tblGNFA qs d

-- 전이함수를 순서쌍 데이타로
d2tblGNFA qs d = [((q1,q2), d(q1,q2)) | q1<-qs, q2<-qs]

-- %%
import Data.Maybe (fromJust, fromMaybe)
import Data.List (elemIndex, groupBy, intercalate)

import IHaskell.Display.Graphviz
-- dot "digraph { l -> o; o -> v; v -> e; h -> a ; a -> s; s -> k ; k -> e ; e -> l ; l -> l}"

gnfa2graph :: (Eq q, Eq a, Show q, Show a) => GNFA q a -> String
gnfa2graph (GNFA (qs,as,d,q0,qf))
     = "digraph { node [shape=circle]; rankdir=LR; "
    ++ "thestart [shape=none label=\"\" width=0]; "
    ++ "thestart -> "++show(q2i q0)++"; "
    ++ concat [show i++" [label=\""++(filter (/='"') . show $ i2q i)++"\"]; " | i<-is]
    ++ show(q2i qf)++" [shape=doublecircle]; "
    ++ concat [ show i++" -> "++show j++" [label=\""++filter (/='"') (show r)++"\"]; " | ((i,j),r) <-es]
    ++ "}"
    where
    is = [0 .. length qs-1]
    q2i q = fromJust $ elemIndex q qs
    i2q i = qs !! i
    es = [((i,j), r) | i<-is, i /= q2i qf, j<-is, j /= q2i q0,
              let r = d(i2q i,i2q j), r/=Empty]

drawGNFA :: (Eq q, Eq a, Show q, Show a) => GNFA q a -> Graphviz
drawGNFA = dot . gnfa2graph

-- %%
import Data.List ( (\\) )

rip q (GNFA (qs,as,d,q0,qf))
    | q == q0 = error "cannot rip start state"
    | q == qf = error "cannot rip final state"
    | q `elem` qs = GNFA (qs',as,d',q0,qf)
    | otherwise = error "invalid state"
    where
    qs' = qs \\ [q]
    d'(qi,qj)
        | q==qi || q==qj = error "ripped state"
        | otherwise = simplify $ Concat r1 (Concat (Star r2) r3) `Union` r4
        where
        r1 = d(qi,q )
        r2 = d(q ,q )
        r3 = d(q ,qj)
        r4 = d(qi,qj)

simplify r 
    | r == r'   = r
    | otherwise = simplify r'
    where r' = simp r

simp (Concat Empty _) = Empty
simp (Concat _ Empty) = Empty
simp (Concat Epsilon r) = r 
simp (Concat r Epsilon) = r
simp (Concat r1 r2) = Concat (simp r1) (simp r2)
simp (Union Empty r) = r
simp (Union r Empty) = r
simp (Union r1 r2) = Union (simp r1) (simp r2)
simp (Star Empty) = Empty
simp (Star Epsilon) = Epsilon
simp (Star r) = Star (simp r)
simp r = r

-- %%
-- q0,qf는 qs에 없는 새로운 상태
dfa2gnfa :: (Eq q, Eq a, Show q, Show a) => DFA q a -> q -> q -> GNFA q a
dfa2gnfa (DFA (qs,as,d,p0,fs)) q0 qf = GNFA (q0:qf:qs,as,d',q0,qf)
    where
    qqs = [(q1,q2) | q1<-qs, q2<-qs]
    es = d2tblDFA qs as d
    es' = [ ((q1,q2),as) | q1<-qs, q2<-qs,
                 let as = [a | ((q1',a),q2')<-es, q1==q1', q2==q2'], not (null as) ]
    d'(q1,q2) | q1 == q0 = if q2 == p0     then Epsilon else Empty
    d'(q1,q2) | q2 == qf = if q1 `elem` fs then Epsilon else Empty
    d'(q1,q2) = maybe Empty (foldr1 Union . map Symbol) $ lookup (q1,q2) es'

-- %%
dfa67a = DFA ([1,2],["a","b"],d,1,[2])
    where
    d(1,"a") = 1; d(1,"b") = 2
    d(2,"a") = 2; d(2,"b") = 2

drawDFA dfa67a

-- %%
gnfa67b = dfa2gnfa dfa67a 0 3

drawGNFA gnfa67b

-- %%
gnfa67c = rip 2 gnfa67b

drawGNFA gnfa67c

-- %%
gnfa67d = rip 1 gnfa67c

drawGNFA gnfa67d

-- %%
-- Figure 1.69

-- %% [markdown]
-- ----
-- ## 1.4 Nonregular Languages
--
-- ### The pumping lemma for regular languages
